# %%
import numpy as np
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats
import depth_tools as tool
# %matplotlib inline

mpl.rcParams['axes.xmargin'] = 0
mpl.rcParams['axes.ymargin'] = 0

# %%
ROOT = '../../data/'
BOARD = ROOT + 'board/'
RENDER = ROOT + 'render_params/'
OUT = '../../output/check_shading-shape/'
size = 60

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 600
y = 800
###################################################
idx = 0
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 2
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 4
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 6
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_v.pdf')
plt.savefig(OUT+'slice_compare_v.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 600
y = 600
###################################################
idx = 0
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 2
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 4
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 6
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_v_y=600.pdf')
plt.savefig(OUT+'slice_compare_v_y=600.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 600
y = 1100
###################################################
idx = 0
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 2
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 4
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 6
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_v_y=1100.pdf')
plt.savefig(OUT+'slice_compare_v_y=1100.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 400
y = 800
###################################################
idx = 0
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 2
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 4
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 6
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_v_x=400.pdf')
plt.savefig(OUT+'slice_compare_v_x=400.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 900
y = 800
###################################################
idx = 0
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 2
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 4
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 6
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_v_x=900.pdf')
plt.savefig(OUT+'slice_compare_v_x=900.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 600
y = 800
###################################################
idx = 1
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 3
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 5
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 7
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_h.pdf')
plt.savefig(OUT+'slice_compare_h.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 600
y = 600
###################################################
idx = 1
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 3
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 5
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 7
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_h_y=600.pdf')
plt.savefig(OUT+'slice_compare_h_y=600.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 600
y = 1100
###################################################
idx = 1
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 3
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 5
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 7
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_h_y=1100.pdf')
plt.savefig(OUT+'slice_compare_h_y=1100.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 300
y = 800
###################################################
idx = 1
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 3
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 5
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 7
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_h_x=300.pdf')
plt.savefig(OUT+'slice_compare_h_x=300.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Right')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Left')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Up')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Down')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = RENDER
x = 900
y = 800
###################################################
idx = 1
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 3
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 5
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 7
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_h_x=900.pdf')
plt.savefig(OUT+'slice_compare_h_x=900.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('V, y=100')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('V, y=1000')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('H, y=100')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('H, y=1000')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
DIR = BOARD
x = 1000
y = 100
idx = 48

shade = cv2.imread(DIR + 'shading/shading{:03d}.bmp'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec_ajusted/depth{:03d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/gt{:03d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
y = 1000

shade = cv2.imread(DIR + 'shading/shading{:03d}.bmp'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec_ajusted/depth{:03d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/gt{:03d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :] = 255

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
idx = 49
x = 1000
y = 100

shade = cv2.imread(DIR + 'shading/shading{:03d}.bmp'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec_ajusted/depth{:03d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/gt{:03d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
y = 1000

shade = cv2.imread(DIR + 'shading/shading{:03d}.bmp'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec_ajusted/depth{:03d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/gt{:03d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))
###################################################
plt.savefig(OUT+'slice_compare_board.pdf')
plt.savefig(OUT+'slice_compare_board.svg')
plt.show()
