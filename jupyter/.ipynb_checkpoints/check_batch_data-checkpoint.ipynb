# %%
import numpy as np
import matplotlib.pyplot as plt

import depth_tools as tool

# %%
data_dir = '../../data/patch_wave1/train/'
data_dir = '../../data/patch_wave2_1000/train/'

# %%
in0 = np.load(data_dir + 'in/00000.npy')
gt0 = np.load(data_dir + 'gt/00000.npy')

# %%
in0.shape
# Out:
# (64, 120, 120, 3)

# %%
gt0.shape
# Out:
# (64, 120, 120, 2)

# %%
in_p = in0[0, :, :, :]
in_p.shape
# Out:
# (120, 120, 3)

# %%
in_p[:10, :10, 0]
# Out:
# array([[ 0.98581188, -0.33752833, -2.06597267, -2.55209764, -2.11998656,
#         -0.60759775,  1.09383965,  0.52669385, -0.17548667, -0.2565075 ],
#        [ 0.98581188,  0.55370079, -1.3907991 , -2.44406987, -2.47107681,
#         -1.55284076,  0.4996869 ,  1.01281882,  0.17560359, -0.2565075 ],
#        [ 0.55370079,  1.0668327 , -0.41854915, -2.09297961, -2.74114624,
#         -2.25502127, -0.60759775,  1.03982576,  0.6887355 , -0.09446584],
#        [ 0.17560359,  0.8777841 ,  0.58070773, -1.30977827, -2.66012541,
#         -2.74114624, -1.44481298,  0.33764525,  0.98581188,  0.28363136],
#        [-0.04045195,  0.33764525,  1.09383965, -0.22950055, -2.20100739,
#         -2.79516013, -2.11998656, -0.49956998,  0.95880493,  0.63472162],
#        [-0.28351444, -0.01344501,  0.85077716,  0.66172856, -1.30977827,
#         -2.60611153, -2.49808376, -1.36379216,  0.28363136,  0.98581188],
#        [-0.28351444, -0.28351444,  0.4996869 ,  1.12084659, -0.36453527,
# ...

# %%
in_p[:10, :10, 1]
# Out:
# array([[1.01706362, 1.01710558, 1.01714897, 1.01719403, 1.01724052,
#         1.01728845, 1.01733804, 1.01738906, 1.01744175, 1.01749635],
#        [1.01715302, 1.0171988 , 1.01724601, 1.01729465, 1.01734471,
#         1.01739621, 1.01744914, 1.0175035 , 1.01755929, 1.01761675],
#        [1.01725006, 1.01729941, 1.0173502 , 1.01740241, 1.01745605,
#         1.01751089, 1.01756716, 1.01762438, 1.01768303, 1.01774311],
#        [1.01735473, 1.01740742, 1.01746178, 1.01751733, 1.01757431,
#         1.01763225, 1.01769137, 1.01775146, 1.01781273, 1.01787496],
#        [1.01746631, 1.01752257, 1.01758003, 1.01763868, 1.01769853,
#         1.01775932, 1.01782107, 1.01788378, 1.0179472 , 1.01801157],
#        [1.0175848 , 1.01764393, 1.01770449, 1.017766  , 1.01782846,
#         1.01789188, 1.01795578, 1.01802039, 1.01808572, 1.01815152],
#        [1.01770926, 1.01777124, 1.01783442, 1.01789832, 1.01796317,
#         1.0180285 , 1.0180943 , 1.01816058, 1.01822734, 1.0182941 ],
# ...

# %%
in_p[:10, :10, 2]
# Out:
# array([[0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.        , 0.        , 0.01568627, 0.03529412, 0.03921569],
#        [0.        , 0.        , 0.        , 0.        , 0.        ,
#         0.03529412, 0.18431373, 0.26666667, 0.21176471, 0.1254902 ],
#        [0.        , 0.        , 0.        , 0.        , 0.01176471,
#         0.08627451, 0.36862745, 0.62745098, 0.57254902, 0.49019608],
#        [0.00392157, 0.        , 0.        , 0.00392157, 0.03529412,
#         0.16862745, 0.43529412, 0.65098039, 0.69803922, 0.59215686],
#        [0.09019608, 0.02745098, 0.03137255, 0.05882353, 0.13333333,
#         0.25490196, 0.34117647, 0.45098039, 0.41176471, 0.37647059],
#        [0.42745098, 0.41568627, 0.41960784, 0.44705882, 0.41176471,
#         0.27843137, 0.21960784, 0.09019608, 0.02352941, 0.00392157],
#        [0.50196078, 0.5372549 , 0.65490196, 0.76078431, 0.58039216,
#         0.3254902 , 0.09019608, 0.01176471, 0.        , 0.        ],
# ...

# %%
gt_p = gt0[0, :, :, :]

# %%
gt_p[:10, :10, 0]
# Out:
# array([[ 1.86784476,  1.84758199,  1.49958274,  0.88482124,  0.17060483,
#         -0.41961826, -0.69827792, -0.59064354, -0.16828547,  0.40892483],
#        [ 1.78753724,  1.92640233,  1.73121044,  1.21571796,  0.5044759 ,
#         -0.19208029, -0.6557075 , -0.75107268, -0.48672709,  0.01129107],
#        [ 1.60164021,  1.89256907,  1.86896015,  1.49493531,  0.84448158,
#          0.09922036, -0.51070781, -0.80089308, -0.71556634, -0.33391973],
#        [ 1.3134998 ,  1.73715915,  1.88866523,  1.68529387,  1.14749375,
#          0.4171043 , -0.28354163, -0.74047655, -0.83918787, -0.60365633],
#        [ 0.9437506 ,  1.46965331,  1.78344751,  1.76113987,  1.37484582,
#          0.71862929, -0.01045889, -0.59027174, -0.86149552, -0.78992516],
#        [ 0.516931  ,  1.10808358,  1.55721082,  1.71131946,  1.50051222,
#          0.96810311,  0.27024564, -0.38113758, -0.79847642, -0.89105315],
#        [ 0.06055378,  0.67327041,  1.22408333,  1.54103777,  1.51835834,
# ...

# %%
gt_p[:10, :10, 1]
# Out:
# array([[1.01706362, 1.01710558, 1.01714897, 1.01719403, 1.01724052,
#         1.01728845, 1.01733804, 1.01738906, 1.01744175, 1.01749635],
#        [1.01715302, 1.0171988 , 1.01724601, 1.01729465, 1.01734471,
#         1.01739621, 1.01744914, 1.0175035 , 1.01755929, 1.01761675],
#        [1.01725006, 1.01729941, 1.0173502 , 1.01740241, 1.01745605,
#         1.01751089, 1.01756716, 1.01762438, 1.01768303, 1.01774311],
#        [1.01735473, 1.01740742, 1.01746178, 1.01751733, 1.01757431,
#         1.01763225, 1.01769137, 1.01775146, 1.01781273, 1.01787496],
#        [1.01746631, 1.01752257, 1.01758003, 1.01763868, 1.01769853,
#         1.01775932, 1.01782107, 1.01788378, 1.0179472 , 1.01801157],
#        [1.0175848 , 1.01764393, 1.01770449, 1.017766  , 1.01782846,
#         1.01789188, 1.01795578, 1.01802039, 1.01808572, 1.01815152],
#        [1.01770926, 1.01777124, 1.01783442, 1.01789832, 1.01796317,
#         1.0180285 , 1.0180943 , 1.01816058, 1.01822734, 1.0182941 ],
# ...

# %%
np.max(gt_p[:10, :10, 0])
# Out:
# 1.9264023299752562

# %%
np.min(gt_p[:10, :10, 0])
# Out:
# -1.107623193617208
