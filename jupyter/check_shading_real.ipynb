# %%
import numpy as np
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats
import depth_tools as tool
# %matplotlib inline

mpl.rcParams['axes.xmargin'] = 0
mpl.rcParams['axes.ymargin'] = 0

# %%
DIR = '../../data/real/'
OUT = '../../output/check_shading/'
size = 120

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Shoes Left')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Shoes Right')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Mesh')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Basket')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
idx = 0
x = 400
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))

shade_rgb = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 1)
shade_rgb[y:y+size, x, 0] = 255
shade_rgb[y:y+size, x+size, 0] = 255
shade_rgb[y, x:x+size, 0] = 255
shade_rgb[y+size, x:x+size, 0] = 255
shade_rgb[y:y+size, x, 1:3] = 0
shade_rgb[y:y+size, x+size, 1:3] = 0
shade_rgb[y, x:x+size, 1:3] = 0
shade_rgb[y+size, x:x+size, 1:3] = 0
###################################################
idx = 0
x = 700
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))

shade_rgb[y:y+size, x, 0] = 255
shade_rgb[y:y+size, x+size, 0] = 255
shade_rgb[y, x:x+size, 0] = 255
shade_rgb[y+size, x:x+size, 0] = 255
shade_rgb[y:y+size, x, 1:3] = 0
shade_rgb[y:y+size, x+size, 1:3] = 0
shade_rgb[y, x:x+size, 1:3] = 0
shade_rgb[y+size, x:x+size, 1:3] = 0
cv2.imwrite(OUT + 'slice_loc_shoes.png', shade_rgb)
###################################################
idx = 9
x = 400
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))

shade_rgb = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 1)
shade_rgb[y:y+size, x, 0] = 255
shade_rgb[y:y+size, x+size, 0] = 255
shade_rgb[y, x:x+size, 0] = 255
shade_rgb[y+size, x:x+size, 0] = 255
shade_rgb[y:y+size, x, 1:3] = 0
shade_rgb[y:y+size, x+size, 1:3] = 0
shade_rgb[y, x:x+size, 1:3] = 0
shade_rgb[y+size, x:x+size, 1:3] = 0
cv2.imwrite(OUT + 'slice_loc_mesh.png', shade_rgb)
###################################################
idx = 17
x = 400
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))

shade_rgb = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 1)
shade_rgb[y:y+size, x, 0] = 255
shade_rgb[y:y+size, x+size, 0] = 255
shade_rgb[y, x:x+size, 0] = 255
shade_rgb[y+size, x:x+size, 0] = 255
shade_rgb[y:y+size, x, 1:3] = 0
shade_rgb[y:y+size, x+size, 1:3] = 0
shade_rgb[y, x:x+size, 1:3] = 0
shade_rgb[y+size, x:x+size, 1:3] = 0
cv2.imwrite(OUT + 'slice_loc_basket.png', shade_rgb)
###################################################
plt.savefig(OUT+'slice_compare.pdf')
plt.savefig(OUT+'slice_compare.svg')
plt.show()

# %%
fig, ax = plt.subplots(2, 4, figsize=(12,6))

ax[0, 0].set_title('Shoes Left')
ax[0, 0].axis('off')
ax[1, 0].set_ylim(-3, 3)

ax[0, 1].set_title('Shoes Right')
ax[0, 1].axis('off')
ax[1, 1].set_ylim(-3, 3)

ax[0, 2].set_title('Mesh')
ax[0, 2].axis('off')
ax[1, 2].set_ylim(-3, 3)

ax[0, 3].set_title('Basket')
ax[0, 3].axis('off')
ax[1, 3].set_ylim(-3, 3)

###################################################
idx = 0
x = 415
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2, 0] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))

shade_rgb = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 1)
shade_rgb[y:y+size, x, 0] = 255
shade_rgb[y:y+size, x+size, 0] = 255
shade_rgb[y, x:x+size, 0] = 255
shade_rgb[y+size, x:x+size, 0] = 255
shade_rgb[y:y+size, x, 1:3] = 0
shade_rgb[y:y+size, x+size, 1:3] = 0
shade_rgb[y, x:x+size, 1:3] = 0
shade_rgb[y+size, x:x+size, 1:3] = 0
###################################################
idx = 0
x = 708
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[:, size//2]
slice_diff = depth[:, size//2] - gt[:, size//2]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[:, size//2, 0] = 255
shade_3ch = cv2.rotate(shade_3ch, cv2.ROTATE_90_COUNTERCLOCKWISE)

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))

shade_rgb[y:y+size, x, 0] = 255
shade_rgb[y:y+size, x+size, 0] = 255
shade_rgb[y, x:x+size, 0] = 255
shade_rgb[y+size, x:x+size, 0] = 255
shade_rgb[y:y+size, x, 1:3] = 0
shade_rgb[y:y+size, x+size, 1:3] = 0
shade_rgb[y, x:x+size, 1:3] = 0
shade_rgb[y+size, x:x+size, 1:3] = 0
cv2.imwrite(OUT + 'slice_loc_shoes.png', shade_rgb)
###################################################
idx = 9
x = 330
y = 630
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))

shade_rgb = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 1)
shade_rgb[y:y+size, x, 0] = 255
shade_rgb[y:y+size, x+size, 0] = 255
shade_rgb[y, x:x+size, 0] = 255
shade_rgb[y+size, x:x+size, 0] = 255
shade_rgb[y:y+size, x, 1:3] = 0
shade_rgb[y:y+size, x+size, 1:3] = 0
shade_rgb[y, x:x+size, 1:3] = 0
shade_rgb[y+size, x:x+size, 1:3] = 0
cv2.imwrite(OUT + 'slice_loc_mesh.png', shade_rgb)
###################################################
idx = 17
x = 900
y = 510
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))

shade_rgb = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 1)
shade_rgb[y:y+size, x, 0] = 255
shade_rgb[y:y+size, x+size, 0] = 255
shade_rgb[y, x:x+size, 0] = 255
shade_rgb[y+size, x:x+size, 0] = 255
shade_rgb[y:y+size, x, 1:3] = 0
shade_rgb[y:y+size, x+size, 1:3] = 0
shade_rgb[y, x:x+size, 1:3] = 0
shade_rgb[y+size, x:x+size, 1:3] = 0
cv2.imwrite(OUT + 'slice_loc_basket.png', shade_rgb)
###################################################
plt.savefig(OUT+'slice_compare.pdf')
plt.savefig(OUT+'slice_compare.svg')
plt.show()

# %%
idx = 0
x = 400
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

# fig_tmp, ax_tmp = plt.subplots(1, 2, figsize=(8, 4))
# ax_tmp[0].imshow(shade_3ch)
# ax_tmp[0].axis('off')
# ax_tmp[1].plot(range(size), scipy.stats.zscore(slice_shade))
# ax_tmp[1].plot(range(size), scipy.stats.zscore(slice_diff))
# ax_tmp[1].set_ylim(-3, 3)

ax[0, 0].imshow(shade_3ch)
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 0].plot(range(size), scipy.stats.zscore(slice_diff))

# %%
idx = 0
x = 700
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

# fig_tmp, ax_tmp = plt.subplots(1, 2, figsize=(8, 4))
# ax_tmp[0].imshow(shade_3ch)
# ax_tmp[0].axis('off')
# ax_tmp[1].plot(range(size), scipy.stats.zscore(slice_shade))
# ax_tmp[1].plot(range(size), scipy.stats.zscore(slice_diff))
# ax_tmp[1].set_ylim(-3, 3)

ax[0, 1].imshow(shade_3ch)
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 1].plot(range(size), scipy.stats.zscore(slice_diff))

# %%
idx = 9
x = 400
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

# fig_tmp, ax_tmp = plt.subplots(1, 2, figsize=(8, 4))
# ax_tmp[0].imshow(shade_3ch)
# ax_tmp[0].axis('off')
# ax_tmp[1].plot(range(size), scipy.stats.zscore(slice_shade))
# ax_tmp[1].plot(range(size), scipy.stats.zscore(slice_diff))
# ax_tmp[1].set_ylim(-3, 3)

ax[0, 2].imshow(shade_3ch)
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 2].plot(range(size), scipy.stats.zscore(slice_diff))

# %%
idx = 17
x = 400
y = 750
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

shade_3ch = np.dstack([shade, shade, shade])
shade_3ch[size//2, :, 0] = 255

# fig_tmp, ax_tmp = plt.subplots(1, 2, figsize=(8, 4))
# ax_tmp[0].imshow(shade_3ch)
# ax_tmp[0].axis('off')
# ax_tmp[1].plot(range(size), scipy.stats.zscore(slice_shade))
# ax_tmp[1].plot(range(size), scipy.stats.zscore(slice_diff))
# ax_tmp[1].set_ylim(-3, 3)

ax[0, 3].imshow(shade_3ch)
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_shade))
ax[1, 3].plot(range(size), scipy.stats.zscore(slice_diff))

# %%
plt.savefig(OUT+'slice_compare.pdf')
plt.show()

# %%
idx = 9
x = 330
y = 630
shade = cv2.imread(DIR + 'shade/{:05d}.png'.format(idx), 0)
shade = shade[y:y+size, x:x+size]
depth = cv2.imread(DIR + 'rec/{:05d}.bmp'.format(idx), -1)
depth = tool.unpack_bmp_bgra_to_float(depth[y:y+size, x:x+size])
gt = cv2.imread(DIR + 'gt/{:05d}.bmp'.format(idx), -1)
gt = tool.unpack_bmp_bgra_to_float(gt[y:y+size, x:x+size])

slice_shade = shade[size//2, :]
slice_diff = depth[size//2, :] - gt[size//2, :]

print(depth[size//2, :])
print(gt[size//2, :])

plt.plot(range(size), slice_diff)
# plt.plot(range(size), scipy.stats.zscore(slice_diff))
# Out:
# [8.67488980e-01 8.67609024e-01 8.67728949e-01 8.67848992e-01
#  8.67969036e-01 8.68098974e-01 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 2.98023224e-08 2.98023224e-08 2.98023224e-08
#  2.98023224e-08 8.76549006e-01 8.76668930e-01 8.76778960e-01
#  8.76888990e-01 8.76999021e-01 8.77108932e-01 8.77218962e-01
#  8.77318978e-01 8.77429008e-01 8.77529025e-01 8.77628922e-01
#  8.77718925e-01 8.77828956e-01 8.77918959e-01 8.78008962e-01
#  8.78108978e-01 8.78198981e-01 8.78288984e-01 8.78389001e-01
#  8.78479004e-01 8.78558993e-01 8.78659010e-01 8.78738999e-01
#  8.78829002e-01 8.78919005e-01 8.79009008e-01 8.79088998e-01
#  8.79179001e-01 8.79269004e-01 8.79348993e-01 8.79438996e-01
